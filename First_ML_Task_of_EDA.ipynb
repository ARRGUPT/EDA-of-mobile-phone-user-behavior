# %% [markdown]
# <a href="https://colab.research.google.com/github/ARRGUPT/EDA-of-mobile-phone-user-behavior/blob/main/First_ML_Task_of_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
file_id = '1EbVuGMfhwihflzgM4PFkNNU46WjcWmeA'
download_url = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(download_url)

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                     393.0
# 1        2       OnePlus 9          Android                     268.0
# 2        3    Xiaomi Mi 11          Android                     154.0
# 3        4  Google Pixel 5          Android                     239.0
# 4        5       iPhone 12              iOS                     187.0
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                   1872.0
# 1                         4.7                   1331.0
# 2                         4.0                    761.0
# 3                         4.8                   1676.0
# 4                         4.3                   1367.0
#
#    Number of Apps Installed  Data Usage (MB/day)   Age  Gender  \
# 0                      67.0               1122.0  40.0    Male
# 1                      42.0                944.0  47.0  Female
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User ID                     700 non-null    int64
#  1   Device Model                698 non-null    object
#  2   Operating System            700 non-null    object
#  3   App Usage Time (min/day)    692 non-null    float64
#  4   Screen On Time (hours/day)  689 non-null    float64
#  5   Battery Drain (mAh/day)     688 non-null    float64
#  6   Number of Apps Installed    687 non-null    float64
#  7   Data Usage (MB/day)         693 non-null    float64
#  8   Age                         690 non-null    float64
#  9   Gender                      700 non-null    object
#  10  User Behavior Class         700 non-null    int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 60.3+ KB

# %%
df.isnull().sum()
# Out:
# User ID                        0
# Device Model                   2
# Operating System               0
# App Usage Time (min/day)       8
# Screen On Time (hours/day)    11
# Battery Drain (mAh/day)       12
# Number of Apps Installed      13
# Data Usage (MB/day)            7
# Age                           10
# Gender                         0
# User Behavior Class            0
# dtype: int64

# %%
df.describe()
# Out:
#           User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.000000                692.000000                  689.000000
# mean   342.877143                274.768786                    5.329753
# std    204.528990                177.617612                    3.062285
# min      1.000000                 30.000000                    1.000000
# 25%    168.750000                116.000000                    2.600000
# 50%    339.500000                230.000000                    5.000000
# 75%    512.250000                441.250000                    7.400000
# max    700.000000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               688.000000                687.000000           693.000000
# mean               1540.902616                 51.305677           946.936508
# std                 816.770905                 26.825584           645.134548
# ...

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                     393.0
# 1        2       OnePlus 9          Android                     268.0
# 2        3    Xiaomi Mi 11          Android                     154.0
# 3        4  Google Pixel 5          Android                     239.0
# 4        5       iPhone 12              iOS                     187.0
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                   1872.0
# 1                         4.7                   1331.0
# 2                         4.0                    761.0
# 3                         4.8                   1676.0
# 4                         4.3                   1367.0
#
#    Number of Apps Installed  Data Usage (MB/day)   Age  Gender  \
# 0                      67.0               1122.0  40.0    Male
# 1                      42.0                944.0  47.0  Female
# ...

# %%
df.sample(700)
# Out:
#      User ID    Device Model Operating System  App Usage Time (min/day)  \
# 306      307       OnePlus 9          Android                     243.0
# 195      196  Google Pixel 5          Android                     202.0
# 5          6  Google Pixel 5          Android                      99.0
# 81        82       iPhone 12              iOS                     172.0
# 16        17       OnePlus 9          Android                     132.0
# ..       ...             ...              ...                       ...
# 671      672  Google Pixel 5          Android                     468.0
# 315      316       OnePlus 9          Android                      74.0
# 266      267       iPhone 12              iOS                     181.0
# 202      203    Xiaomi Mi 11          Android                      88.0
# 674      675    Xiaomi Mi 11          Android                     522.0
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# ...

# %%
# Categorical Variables:

# %%
sns.countplot(x='Gender', data=df)
plt.title('Gender Distribution')
plt.show()

# %%
sns.countplot(x='User Behavior Class', data=df)
plt.title('User Behavior Class Distribution')
plt.show()

# %%
sns.countplot(x='Operating System', data=df)
plt.title('Operating System Distribution')
plt.show()

# %%
sns.countplot(y='Device Model', data=df)
plt.title('Device Model Distribution')
plt.show()

# %%
# Continuous Variables:

# %%
sns.histplot(df['App Usage Time (min/day)'], bins=20, kde=True)
plt.title('App Usage Time Distribution')
plt.xlabel('App Usage Time (min/day)')
plt.show()

# %%
sns.histplot(df['Screen On Time (hours/day)'], bins=20, kde=True)
plt.title('Screen On Time Distribution')
plt.xlabel('Screen On Time (hours/day)')
plt.show()

# %%
sns.histplot(df['Battery Drain (mAh/day)'], bins=20, kde=True)
plt.title('Battery Drain Distribution')
plt.xlabel('Battery Drain (mAh/day)')
plt.show()

# %%
sns.histplot(df['Number of Apps Installed'], bins=20, kde=True)
plt.title('Number of Apps Installed Distribution')
plt.xlabel('Number of Apps Installed')
plt.show()

# %%
sns.histplot(df['Data Usage (MB/day)'], bins=20, kde=True)
plt.title('Data Usage Distribution')
plt.xlabel('Data Usage (MB/day)')
plt.show()

# %%
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.show()

# %%
# Relationships and Correlations:

# %%
sns.scatterplot(x='App Usage Time (min/day)', y='Screen On Time (hours/day)', data=df)
plt.title('App Usage Time vs. Screen On Time')
plt.show()

# %%
sns.scatterplot(x='Battery Drain (mAh/day)', y='Data Usage (MB/day)', data=df)
plt.title('Battery Drain vs. Data Usage')
plt.show()

# %%
sns.boxplot(x='Gender', y='App Usage Time (min/day)', data=df)
plt.title('App Usage Time by Gender')
plt.show()

# %%
sns.boxplot(x='User Behavior Class', y='Battery Drain (mAh/day)', data=df)
plt.title('Battery Drain by User Behavior Class')
plt.show()

# %%
# Correlation Analysis:

# %%
plt.figure(figsize=(10, 8))
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df['App Usage Time (min/day)'] = df['App Usage Time (min/day)'].fillna(df['App Usage Time (min/day)'].mean())

Q1 = df['Battery Drain (mAh/day)'].quantile(0.25)
Q3 = df['Battery Drain (mAh/day)'].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df['Battery Drain (mAh/day)'] < (Q1 - 1.5 * IQR)) | (df['Battery Drain (mAh/day)'] > (Q3 + 1.5 * IQR)))]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Battery Drain (mAh/day)', data=df)
plt.title('Box Plot of Battery Drain')
plt.show()

# %%
sns.pairplot(df)
plt.title('Pair Plot of Numerical Variables')
plt.show()

# %%
summary_stats = df.describe()
print(summary_stats)
# Out:
#           User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.000000                700.000000                  689.000000
# mean   342.877143                274.768786                    5.329753
# std    204.528990                176.598277                    3.062285
# min      1.000000                 30.000000                    1.000000
# 25%    168.750000                118.250000                    2.600000
# 50%    339.500000                234.000000                    5.000000
# 75%    512.250000                438.750000                    7.400000
# max    700.000000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               688.000000                687.000000           693.000000
# mean               1540.902616                 51.305677           946.936508
# std                 816.770905                 26.825584           645.134548
# ...
